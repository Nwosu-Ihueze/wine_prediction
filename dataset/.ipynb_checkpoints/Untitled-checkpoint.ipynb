# %% [markdown]
# # Wine Prediction Model

# %% [markdown]
# ##### Importing libraries

# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np

# %% [markdown]
# ##### Reading data from csv file

# %%
white_wine = pd.read_csv("/Users/ada-ihueze/Documents/wine_prediction/dataset/winequality-white.csv", sep =';') 
 
red_wine = pd.read_csv("/Users/ada-ihueze/Documents/wine_prediction/dataset/winequality-red.csv", sep =';')

# %% [markdown]
# ##### Getting the list of the first five wines in the red category

# %%
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ##### Getting the list of the first five wines in the white category

# %%
white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %% [markdown]
# ##### Checking for null values in the red category

# %%
pd.isnull(red)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %% [markdown]
# ##### Checking for null values in the white category

# %%
pd.isnull(white)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 4893          False             False        False           False      False
# 4894          False             False        False           False      False
# 4895          False             False        False           False      False
# 4896          False             False        False           False      False
# 4897          False             False        False           False      False
#
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ##### Creating scatter plots for the white wines

# %%
plt.figure(figsize=(9, 6))

plt.scatter(white['volatile acidity'].values, white['alcohol'].values, c=white['quality'].values, cmap=plt.cm.cubehelix)

plt.xlabel('Acidity')
plt.ylabel('Alcohol')

cbar = plt.colorbar()
cbar.set_label("Quality")

plt.show()

# %% [markdown]
# ##### Creating scatter plots for the red wines

# %%
plt.figure(figsize=(9, 6))

plt.scatter(red['volatile acidity'].values, red['alcohol'].values, c=red['quality'].values, cmap=plt.cm.cubehelix)

plt.xlabel('Acidity')
plt.ylabel('Alcohol')

cbar = plt.colorbar()
cbar.set_label("Quality")

plt.show()

# %% [markdown]
# ##### Plotting histograms for the two brands of wine

# %%
# Create Histogram 
fig, ax = plt.subplots(1, 2,
                      figsize = (10,7)) 
  
ax[0].hist(red.alcohol, 10, facecolor ='red', 
              alpha = 0.5, label ="Red wine") 
  
ax[1].hist(white.alcohol, 10, facecolor ='gold', 
           ec ="black", lw = 0.5, alpha = 0.5, 
           label ="White wine") 
  
fig.subplots_adjust(left = 0, right = 1, bottom = 0,  
               top = 0.5, hspace = 0.05, wspace = 1) 
  
ax[0].set_ylim([0, 1000]) 
ax[0].set_xlabel("Alcohol in % Vol") 
ax[0].set_ylabel("Frequency") 
ax[1].set_ylim([0, 1000]) 
ax[1].set_xlabel("Alcohol in % Vol") 
ax[1].set_ylabel("Frequency") 
  
fig.suptitle("Distribution of Alcohol in % Vol") 
plt.show()

# %% [markdown]
# ##### Splitting data into train and test sets

# %%
# Add `type` column to `red` with price one 
red['type'] = 1
  
# Add `type` column to `white` with price zero 
white['type'] = 0
  
# Append `white` to `red` 
wines = red.append(white, ignore_index = True) 
  
# Import `train_test_split` from `sklearn.model_selection` 
from sklearn.model_selection import train_test_split 
X = wines.iloc[:, 0:11] 
y = np.ravel(wines.type) 
  
# Splitting the data set for training and validating  
X_train, X_test, y_train, y_test = train_test_split( 
           X, y, test_size = 0.34, random_state = 45)

# %% [markdown]
# ##### Building the neural network

# %%
from keras.models import Sequential 
from keras.layers import Dense 
  
model = Sequential()  
model.add(Dense(12, activation ='relu', input_shape =(11, )))  
model.add(Dense(9, activation ='relu'))  
model.add(Dense(1, activation ='sigmoid'))  
model.output_shape 
model.summary() 
model.get_config() 
   
model.get_weights() 
model.compile(loss ='binary_crossentropy',  
  optimizer ='adam', metrics =['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 12)                144
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 117
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 10
# ...
# Total params: 271
# Trainable params: 271
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### Training the model

# %%
model.fit(X_train, y_train, epochs = 3, 
           batch_size = 1, verbose = 1)
# Out:
# Epoch 1/3
# 4288/4288 [==============================] - 12s 3ms/step - loss: 0.7420 - accuracy: 0.8832
# Epoch 2/3
# 4288/4288 [==============================] - 13s 3ms/step - loss: 0.2084 - accuracy: 0.9263
# Epoch 3/3
# 4288/4288 [==============================] - 17s 4ms/step - loss: 0.1702 - accuracy: 0.9387

# %% [markdown]
# ##### Prediction

# %%
y_pred = model.predict(X_test) 
print(y_pred)
# Out:
# [[1.8052220e-02]
#  [4.7556758e-03]
#  [1.2770593e-03]
#  ...
#  [9.0534687e-03]
#  [7.2377622e-03]
#  [6.9022070e-05]]

# %% [markdown]
# ##### Correlation

# %%
import seaborn as sns

# %%
whiteplot=sns.heatmap(white.corr())

# %%
redplot = sns.heatmap(red.corr())

# %% [markdown]
# ##### Saving the model

# %%
model_json = model.to_json()
with open("wine-model.json","w") as json_file:
  json_file.write(model_json)
